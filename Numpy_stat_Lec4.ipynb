# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Numpy_stat_Lec4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
correlation : r^2 --> -1 < x < 1

correlation = [cov(x,y)/std dev]

y = m*x + c  (m = slope)

    (y2 - y1)
m = ----------
    (x2 - x1)

theta(0) = tan^-1(m)

Covariance : never gives quantitative values
positive / negative / zero

'''

# %%
# Measure of Association
'''
a. covariance
b. correlation = (covariance/std)

note:

1. In order to evaluate correlation please ensure all the columns are in one scale

2. there are 3 types of scaling technique
 - standard scaler
 - min-max scaler
 - robust scaler

 note:
 a. when the dataset is normally distributed (symmetric data) then go for standard scaler

 b. when the dataset is non normal distibuted (skewed data) then go for min-max scaler

 c. when the dataset is non normal distributed (skewed) also contain lots of
    outliers then go for robust scaler

'''

# %%
'''
Skewness is classified into three types
  - Positive skewnes
  - Negative skewnes
  - Zero skewness (no skewed/symmetric distribution)

-----------------------------------------------------------

Kurtosis is classified into three types
  - Lepto-kurtic
  - Meso-kurtic
  - Platy-kurtic

'''
