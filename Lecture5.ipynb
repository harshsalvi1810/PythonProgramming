# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Lecture5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# concept of pass,continue and break

for i in range(1,5):
  print(i,end = ' ')
# Out:
# 1 2 3 4

# %%
#break
for i in range(1,5):
  print(i,end = ' ')
  break
# Out:
# 1

# %%
#continue
for i in range(1,5):
  print(i,end = ' ')
  continue
# Out:
# 1 2 3 4

# %%
for i in range(1,5):
  continue
  print(i,end = ' ')        #skip print

# %%
#pass
for i in range(1,5):
  pass

# %%
for i in range(1,5):
  if i % 2 == 0:
    print(i)
  continue
# Out:
# 2
# 4

# %%
#pass break
i = 0
while i <= 5:
  for i in range(1,5):
    pass
    print(i)
    i += 1
  break          #only 1234    not braking for loop
# Out:
# 1
# 2
# 3
# 4

# %%
# i = 0
# while i <= 5:
#   for i in range(1,5):
#     pass
#     print(i)
#     i += 1
#   #  break           #infinte 1 (breaking for loop)

# %%
i = 0
while i <= 5:
  for i in range(1,5):
    i = i + 1
    print(i)
  break
  i += 1
  continue

# %%
'''
logic:

1. ask user to enter name,passcode,acct_no,withdraw_amt,acct_type
2. defined variables: saving_acct = 10000 and current_acct = 2000
3. condition: type == 1 for saving_acct and type == 2 for current_acct
4. if withdraw_amt <= saving_acct : balance  = saving_acct - withdraw_amt
5. if withdraw_amt <= current_acct : balance  = current_acct - withdraw_amt
6. print(balance)

'''

name = input("Enter the name: ")
account_no = int(input("Enter the account no: "))
passcode = int(input("Enter the passcode: "))
withdraw = float(input("Enter the withdraw amount: "))
acct_type = input("Enter the account type: ")

saving = 10000
current = 2000
balance = 0

if acct_type.lower() == "saving":
  if saving >= withdraw:
    balance = saving - withdraw
    print("Balance amount is ",balance)
  elif saving < withdraw:
    print("Insufficient balance")

elif acct_type.lower(35) == "current":
  if current >= withdraw:
    balance = current - withdraw
    print("Balance amount is ",balance)
  elif current < withdraw:
    print("Insufficient balance")

else:
  print("Invalid account type")
# Out:
# Enter the name: afs
# Enter the account no: 53
# Enter the passcode: 253
# Enter the withdraw amount: 5000
# Enter the account type: saving
# Balance amount is  5000.0
