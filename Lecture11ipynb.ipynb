# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Lecture11ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sum = 100
i = 1
if i <= 10:
  i = sum + i
  pass
  if i <= 3:
    print('hii')

    if i <= 2:
      print('world')

print(sum)
# Out:
# 100

# %%
def sum(num1 = 100,num2 = 200):
  num3 = num1 + num2
  print(num3)

sum()
# Out:
# 300

# %%
# defined values after not defined variable
def sum(num3,num1 = 100,num2 = 200):
  num4 = num1 + num2 + num3
  print(num4)

sum(1)    #if sum(1,1,1) then replace all value with 1(i/p)
# Out:
# 301

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))

def calc(num1,num2):
  num3 = num1 + num2
  return num3

ans = calc(a,b)
print(ans)
# Out:
# Enter a number: 12
# Enter a number: 12
# 24
