# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Lecture4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0

while i < 4:
  print(i)
  i = i + 1
# Out:
# 0
# 1
# 2
# 3

# %%
i = 0
while i < 4:
  print(i)
  if i == 1:
    print("Hello")
  i = i + 1
# Out:
# 0
# 1
# Hello
# 2
# 3

# %%
i = 0

while i <= 5:
  if i == 1:
    print("hello")
    if i == 2:
      print("World")

      i = i + 2

  print(i)
  #infite 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7854/1146731280.py in <cell line: 0>()
#       1 i = 0
#       2
# ----> 3 while i <= 5:
#       4   if i == 1:
#       5     print("hello")
#
# KeyboardInterrupt:

# %%
i = 0
while i == 0 and i < 5:
  print(i)
  if i == 2:
    print("you win")
    i += 1

  i = i + 1

  print(i)
# Out:
# 0
# 1

# %%
i = 0
while i == 0 or i < 5:
  print(i)
  if i == 2:
    print("you win")
    i += 1

  i = i + 1

  print(i)
# Out:
# 0
# 1
# 1
# 2
# 2
# you win
# 4
# 4
# 5

# %%
# Mathematical Operators in python

num = 100
num1 = 20

print(num + num1)
print(num - num1)
print(num * num1)
print(num / num1) #ans in float
print(num % num1)
print(num // num1) #ans in int (no upper value)
print(num ** num1) #power
# Out:
# 120
# 80
# 2000
# 5.0
# 0
# 10000000000000000000000000000000000000000
# 5

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator: ")

if operator == "+":
  print(num1 + num2)
elif operator == "-":
  print(num1 - num2)
elif operator == "*":
  print(num1 * num2)
elif operator == "/":
  print(num1 / num)
elif operator == "%":
  print(num1 % num2)
elif operator == "//":
  print(num1 // num2)
elif operator == "**":
  print(num1 ** num2)
else:
  print("Invalid operator")
# Out:
# Enter first number: 45
# Enter second number: 2
# Enter operator:
# Invalid operator

# %%
user_name = "harsh"
password = "1234"

user = input("Enter username: ")
passw = input("Enter password: ")

user = user.lower()

if user_name == user and password == passw:  # if name.lower() == "harsh" and passcode == "1234":
  num1 = float(input("Enter first number: "))
  num2 = float(input("Enter second number: "))
  operator = input("Enter operator: ")

  if operator == "+":
    print(num1 + num2)
  elif operator == "-":
    print(num1 - num2)
  elif operator == "*":
    print(num1 * num2)
  elif operator == "/":
    print(num1 / num)
  elif operator == "%":
    print(num1 % num2)
  elif operator == "//":
    print(num1 // num2)
  elif operator == "**":
    print(num1 ** num2)
  else:
    print("Invalid operator")

else:
  print("Invalid username or password")
# Out:
# Enter username: aasfg
# Enter password: swq2
# Invalid username or password
