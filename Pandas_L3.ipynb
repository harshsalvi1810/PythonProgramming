# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Pandas_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to_datetime = conevrt to "year-month-day"
import numpy as np
from scipy.stats import ttest_1samp
import pandas as pd
a = [48,49,50,52,53,53,54,51,50,49]

# %%
mean = np.mean(a)
print(mean)
t_statistics,p_value = ttest_1samp(a,50)
print(p_value)

if p_value < 0.05:
    print("Reject the null hypothesis")
else:
    print("accept the null hypothesis")
# Out:
# 50.9
# 0.1934220596033329
# accept the null hypothesis
