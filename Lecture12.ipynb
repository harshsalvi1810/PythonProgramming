# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsalvi1810/PythonProgramming/blob/main/Lecture12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# File Handling

df = open('data.txt',mode = 'r')
print(df.read())
# Out:
# i am happyi am happy2i am happy2

# %%
df = open('data.txt',mode = 'r')
print(df.readline())
print(df.readline(2))
# Out:
# i am happyi am happy2i am happy2

# %%
with open('data.txt',mode = 'r') as mydata:
    print(mydata.read())
# Out:
# i am happyi am happy2i am happy2

# %%
with open('data.txt',mode = 'w') as mydata:
    print(mydata.writelines('i am happy'))
# Out:
# None

# %%
with open('data.txt',mode = 'r') as mydata:
    print(mydata.read())
# Out:
# i am happy

# %%
data = open("data.txt","a")
data.writelines("i am happy2")

# %%
with open('data.txt',mode = 'r') as mydata:
    print(mydata.read())
# Out:
# i am happy

# %%
data.close()

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

try:
  ans = num1/num2
  print(ans)

except Exception as e:
  print(e)
# Out:
# Enter first number: 1
# Enter second number: 0
# division by zero

# %%
acc_no = input("Enter account number: ")
mpin = input("Enter mpin: ")

try:
  if acc_no.lower() == "tjsb1234" and mpin == '1234':
    pin = int(input("Enter the pin: "))
    if pin == 5525:
      withdraw_amt = float(input("Enter the amount to withdraw: "))
      balance = 10000
      if withdraw_amt <= balance:
        print("amount withdraw: ",withdraw_amt)
        balance = balance - withdraw_amt
        print("Balance amount: ",balance)
#except Exception as e:
      else:
        print("Insuffisient amount")
    else:
      print("Wrong pin")
  else:
    print("Wrong credentials")
except Exception as e:
  print(e)
# Out:
# Enter account number: tjsb1234
# Enter mpin: 1234
# Enter the pin: 5525
# Enter the amount to withdraw: 5000
# amount withdraw:  5000.0
# Balance amount:  5000.0
